# %%
import openai

# %%
mykey=""

# %%
openai.api_key=mykey

# %%
all_model = openai.models.list()

# %%
list(all_model)
# Out:
# [Model(id='gpt-3.5-turbo-16k-0613', created=1685474247, object='model', owned_by='openai'),
#  Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'),
#  Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'),
#  Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'),
#  Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'),
#  Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'),
#  Model(id='gpt-3.5-turbo-16k', created=1683758102, object='model', owned_by='openai-internal'),
#  Model(id='gpt-3.5-turbo', created=1677610602, object='model', owned_by='openai'),
#  Model(id='gpt-3.5-turbo-0613', created=1686587434, object='model', owned_by='openai'),
#  Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'),
# ...

# %%
import pandas as pd
pd.DataFrame(list(all_model),columns=["id","created","object","owned_by"])
# Out:
#                                    id                created           object  \
# 0        (id, gpt-3.5-turbo-16k-0613)  (created, 1685474247)  (object, model)
# 1                      (id, dall-e-2)  (created, 1698798177)  (object, model)
# 2        (id, text-embedding-3-large)  (created, 1705953180)  (object, model)
# 3                     (id, whisper-1)  (created, 1677532384)  (object, model)
# 4                 (id, tts-1-hd-1106)  (created, 1699053533)  (object, model)
# 5                      (id, tts-1-hd)  (created, 1699046015)  (object, model)
# 6            (id, gpt-3.5-turbo-0125)  (created, 1706048358)  (object, model)
# 7             (id, gpt-3.5-turbo-16k)  (created, 1683758102)  (object, model)
# 8                 (id, gpt-3.5-turbo)  (created, 1677610602)  (object, model)
# 9            (id, gpt-3.5-turbo-0613)  (created, 1686587434)  (object, model)
# 10           (id, gpt-3.5-turbo-0301)  (created, 1677649963)  (object, model)
# ...

# %%
from openai import OpenAI
client = OpenAI(api_key=mykey)

# %%
a = client.chat.completions.create(
    model = "gpt-3.5-turbo",
    messages =[
        {
            "role" : "user",
            "content" : "How to learn AI and ML?"
        }
    ]
)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 a = client.chat.completions.create(
#       2     model = "gpt-3.5-turbo",
#       3     messages =[
#       4         {
#       5             "role" : "user",
#       6             "content" : "How to learn AI and ML?"
#       7         }
#       8     ]
#       9 )
#
# File ~\anaconda3\envs\learn-open-ai\lib\site-packages\openai\_utils\_utils.py:275, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     273             msg = f"Missing required argument: {quote(missing[0])}"
#     274     raise TypeError(msg)
# --> 275 return func(*args, **kwargs)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 a
#
# NameError: name 'a' is not defined
